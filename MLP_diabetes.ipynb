# %% [markdown]
# ### Exemplo de MLP com TensorFlow/Keras em Notebook
#
# Primeiramente, **importar** o dataset para o Drive  e  os pacotes necessários..

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fd610e45-e369-4c5d-a6a5-02c1d1d17c25" name="files[]" multiple disabled />
#      <output id="result-fd610e45-e369-4c5d-a6a5-02c1d1d17c25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pima-indians-diabetes.csv to pima-indians-diabetes.csv
# User uploaded file "pima-indians-diabetes.csv" with length 22591 bytes

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %% [markdown]
# Gerando Seed Random

# %%
seed = 7
numpy.random.seed(seed)

# %% [markdown]
# Carregando o **dataset** e ajustando as matrizes X  e Y (Labels)

# %%
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")

# Separando colunas input (X) e output (Y) 
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# Criando modelo Keras MLP com 3 camadas (64 - 32 - 1)

# %%
model = Sequential()
model.add(Dense(64, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(32, kernel_initializer='uniform', activation='relu'))
model.add(Dense(32, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %% [markdown]
# Compilando e Treinando o Modelo

# %%
# Compilando Modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Treinando Modelo
model.fit(X, Y, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 746/746 [==============================] - 0s 463us/step - loss: 0.6870 - acc: 0.6542
# Epoch 2/20
# 746/746 [==============================] - 0s 18us/step - loss: 0.6759 - acc: 0.6542
# Epoch 3/20
# 746/746 [==============================] - 0s 25us/step - loss: 0.6653 - acc: 0.6542
# Epoch 4/20
# 746/746 [==============================] - 0s 31us/step - loss: 0.6583 - acc: 0.6542
# Epoch 5/20
# 746/746 [==============================] - 0s 19us/step - loss: 0.6515 - acc: 0.6542
# Epoch 6/20
# 746/746 [==============================] - 0s 21us/step - loss: 0.6449 - acc: 0.6568
# Epoch 7/20
# 746/746 [==============================] - 0s 34us/step - loss: 0.6353 - acc: 0.6568
# Epoch 8/20
# 746/746 [==============================] - 0s 29us/step - loss: 0.6258 - acc: 0.6582
# Epoch 9/20
# 746/746 [==============================] - 0s 31us/step - loss: 0.6171 - acc: 0.6595
# Epoch 10/20
# 746/746 [==============================] - 0s 31us/step - loss: 0.6058 - acc: 0.6823
# Epoch 11/20
# 746/746 [==============================] - 0s 29us/step - loss: 0.6042 - acc: 0.6877
# Epoch 12/20
# 746/746 [==============================] - 0s 31us/step - loss: 0.5974 - acc: 0.6890
# Epoch 13/20
# 746/746 [==============================] - 0s 28us/step - loss: 0.5934 - acc: 0.6877
# Epoch 14/20
# 746/746 [==============================] - 0s 22us/step - loss: 0.5908 - acc: 0.6850
# Epoch 15/20
# 746/746 [==============================] - 0s 21us/step - loss: 0.5881 - acc: 0.6984
# Epoch 16/20
# 746/746 [==============================] - 0s 20us/step - loss: 0.5878 - acc: 0.6903
# Epoch 17/20
# 746/746 [==============================] - 0s 27us/step - loss: 0.5841 - acc: 0.6930
# Epoch 18/20
# 746/746 [==============================] - 0s 30us/step - loss: 0.5796 - acc: 0.6903
# Epoch 19/20
# 746/746 [==============================] - 0s 37us/step - loss: 0.5764 - acc: 0.6984
# Epoch 20/20
# 746/746 [==============================] - 0s 31us/step - loss: 0.5758 - acc: 0.6997

# %% [markdown]
# Avaliando o modelo e imprimindo o Resumo (Summary) da Rede Neural

# %%
# Avaliando Modelo
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))


# Resumo da Rede
print(model.summary())
# Out:
# 746/746 [==============================] - 0s 109us/step
# acc: 70.24%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                576
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 3,745
# Trainable params: 3,745
# Non-trainable params: 0
# _________________________________________________________________
# None
